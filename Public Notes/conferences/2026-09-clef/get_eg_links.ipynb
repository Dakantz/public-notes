# %%
import requests as rq
import bs4

# %%
import json
import re


def get_eg_link(title):
    params = {
        "sort": "score,DESC",
        "page": 0,
        "size": 10,
        "query": f'"{title}"',
        "f.dateIssued": "[2007 TO *],equals",
        "embed": "thumbnail, item/thumbnail",
    }
    r = rq.get(
        "https://diglib.eg.org/server/api/discover/search/objects",
        params,
    ).json()
    res_list = r["_embedded"]["searchResult"]["_embedded"]["objects"]
    res_object = res_list[0] if len(res_list) > 0 else None
    # print(json.dumps(res_object, indent=2))
    if res_object is None:
        return {}
    link = f"https://diglib.eg.org/items/{res_object['_embedded']['indexableObject']['id']}"
    doi = res_object["_embedded"]["indexableObject"]["handle"]
    authors = res_object["_embedded"]["indexableObject"]["metadata"][
        "dc.contributor.author"
    ]
    abstr = res_object["_embedded"]["indexableObject"]["metadata"].get(
        "dc.description.abstract", []
    )
    thumbnail = res_object["_embedded"]["indexableObject"]["_embedded"]["thumbnail"]["_links"]["content"]["href"]
    author_names = [a["value"] for a in authors]
    return {
        "link": link,
        "doi": doi,
        "authors": author_names,
        "abstr": abstr,
        "thumbnail": thumbnail
    }


resp = get_eg_link("Parameter Space Analysis through Guided Visual Interpolations")

# %%
program_html=rq.get("https://conferences.eg.org/vcbm2026/full-program/").text

# %%
soup = bs4.BeautifulSoup(program_html, "html.parser")

# %%
entries = list(soup.find("div", class_="entry-content").children)
day = ""
timeslot = ""
import dataclasses


@dataclasses.dataclass
class Paper:
    day: str
    timeslot: str
    title: str
    link: str
    authors: str
    doi: str = ""
    thumbnail: str = ""


papers = []
for entry in entries:
    if entry.name == "h3":
        day = entry.text
    elif entry.name == "h5":
        timeslot = entry.text
    elif entry.name == "div":
        talks = entry.find_all("p")
        for talk in talks:
            if talk.find("strong") is None:
                continue
            name = talk.find("strong").text
            link = talk.find("a")["href"] if talk.find("a") is not None else ""
            authors = talk.find("em").text if talk.find("em") is not None else ""
            paper = Paper(
                day=day, timeslot=timeslot, title=name, link=link, authors=authors
            )
            papers.append(paper)
            print(f"{day} | {timeslot} | {name} | {link} | {authors}")
# Out:
# Wednesday, September 16 | 16:30 onwards • Poster & Demo Session with Welcome Reception | Interactive Visualization of Dynamic Functional Connectivity in the ABIDE Autism Dataset | https://conferences.eg.org/vcbm2026/wp-content/uploads/sites/27/2026/09/Schielen_ABIDE.pdf | Daniel Eliad, Sjir J.C. Schielen, Albert P. Aldenkamp, Danny Ruijters, Svitlana Zinger
# Wednesday, September 16 | 16:30 onwards • Poster & Demo Session with Welcome Reception | Effective Guidance in Immersive, Simulation-based Ophthalmology Education | https://conferences.eg.org/vcbm2026/wp-content/uploads/sites/27/2026/09/Zaitseva_GuidanceVR.pdf | Mariia Zaitseva, Doğukan Zal, Peter Walter, Torsten Kuhlen, Tim Gerrits
# Wednesday, September 16 | 16:30 onwards • Poster & Demo Session with Welcome Reception | MindJourneys: An Interactive Narrative Visualization of Depression Case Reports | https://conferences.eg.org/vcbm2026/wp-content/uploads/sites/27/2026/09/Swadia_MindJourneys.pdf | Dhruvi Gaurav Swadia, Nivedita Kowlagi, Bernhard Preim, Monique Meuschke
# Thursday, September 17 | 10:30 – 12:00 • Paper Session 1 – Molecules, Genes & Neurons | ConGAT: Context-Aware Graph Attention Visual Analysis for 3D Region of Interest Discovery in Multiplexed Microscopy Images |  | Hossein Fathollahian, Siyuan Zhao, Nafiul Nipu, Marziye Salahshour, Lei Duan, Wei Tang, Saeed Boorboor, Elisabeta Marai
# Thursday, September 17 | 10:30 – 12:00 • Paper Session 1 – Molecules, Genes & Neurons | MultiPASE: Shape-Aware Comparative 3D Genome Analysis |  | Md Nafiul Alam Nipu, Graham Johnson, Cullen Roth, David Rogers, Shawn Starkenburg, Christina Steadman, Elisabeta Marai
# Thursday, September 17 | 10:30 – 12:00 • Paper Session 1 – Molecules, Genes & Neurons | Exploring Genes in the Brain Through Multimodal Views Driven by Disorder Ontologies |  | Benedikt Kantz, Mattia Veronese, Alessio Giacomel, Ivelina Nikolova, Gianmaria Silvello, Peter Waldert, Stefan Lengauer, Tobias Schreck
# Thursday, September 17 | 10:30 – 12:00 • Paper Session 1 – Molecules, Genes & Neurons | Interactive 3D Exploration of Large-Scale Neuronal Network Simulations with a Graph Lens |  | Peter Waldert, Benedikt Kantz, Gaia Tussardi, Stefan Lengauer, Tobias Schreck
# Thursday, September 17 | 10:30 – 12:00 • Paper Session 1 – Molecules, Genes & Neurons | An End-to-end Framework for Quantifying the Exploratory Behavior of Multicolumnar Neurons in Drosophila |  | Blaž Brence, Sajjad Khawari, Maria Ahmed, Daniel Baum
# Thursday, September 17 | 13:00 – 14:30 • Paper Session 2 – Anatomy, Meshes & Surgical Planning | Accurate Triangle Meshes of Biological Membranes Through Ridge Surface Reconstruction |  | Nicolas Klenert, Patricia Loba-Gómez, Leiss Abdal Al, Juan Diego Gallego Nicolás, Harold Phelippeau, Rachida Seghiri, Antonio Martinez-Sanchez, Daniel Baum
# Thursday, September 17 | 13:00 – 14:30 • Paper Session 2 – Anatomy, Meshes & Surgical Planning | Reconstruction of 3D Whole Heart Mesh from 2D Cardiac Images |  | Lisa Bautz, Stine Hoffmann, Johanna Brosig, Markus Hüllebrand, Franziska Seidel, Anja Hennemuth
# Thursday, September 17 | 13:00 – 14:30 • Paper Session 2 – Anatomy, Meshes & Surgical Planning | Vessel-straightening-based Registration for Aortic Flow Comparison |  | Aaron Schroeder, Anja Horvat, Kai Ostendorf, Kathrin Bäumler, Domenico Mastrodicasa, Nina Kerschbaumer, Dominik Fleischmann, Bernhard Preim, Gabriel Mistelbauer
# Thursday, September 17 | 13:00 – 14:30 • Paper Session 2 – Anatomy, Meshes & Surgical Planning | Formalizing Structured Comparative Reporting for Hemodynamic Assessment in LAAO Planning |  | Jasna Nuhic, Monique Meuschke, Oscar Camara
# Thursday, September 17 | 13:00 – 14:30 • Paper Session 2 – Anatomy, Meshes & Surgical Planning | Coupled Visualization-Quantification Pipeline for Time-Resolved Cement Injection Imaging: A Case Study |  | Isha Sharma, Jan-Sören Lennart Völter, Dominic Gehweiler, Oliver Röhrle, Dieter Schmalstieg
# Thursday, September 17 | 15:00 – 16:30 • Paper Session 3 – Multimodal Systems & Biosignals | MIA: A Visual Analytics System for Multimodal Spectral Imaging Data |  | Hennes Rave, Katharina Kronenberg, Hannes Gödde, Lea Tobergte, Michael Holtkamp, Julia Werner, Peter Bohrer, Fabian Lohöfer, Rickmer Braren, David Clases, Uwe Karst, Lars Linsen
# Thursday, September 17 | 15:00 – 16:30 • Paper Session 3 – Multimodal Systems & Biosignals | BeLOVE X-Talker: Interactive Heart-Brain Cross-Talk Explorer |  | Markus Huellebrand, Ann Philine Laube, Huma Fatima Ali, Joachim Weber, Ira Magdalena Rohrpasser-Napierkowski, Jeanette Schulz-Menger, Kersten Villringer, Anja Hennemuth
# Thursday, September 17 | 15:00 – 16:30 • Paper Session 3 – Multimodal Systems & Biosignals | GutBrainViz: Interactive Exploration of Linked ICA Components across Brain Networks and Gut Microbiota |  | Casper van Leeuwen
# Thursday, September 17 | 15:00 – 16:30 • Paper Session 3 – Multimodal Systems & Biosignals | EEGlass: A Fully Interpretable EEG Dementia Screening Assistant |  | Peter Waldert, Michael Grabner, Lukas Schilcher, Niklas Tscheppe, Gaia Tussardi, Benedikt Kantz, Stefan Lengauer, Tobias Schreck
# Thursday, September 17 | 15:00 – 16:30 • Paper Session 3 – Multimodal Systems & Biosignals | Voidlytics for Leveraging Informative Missingness in the Study of Hyperemesis Gravidarum |  | Hanna Balaka, Ke Er Zhang, Marta Czinkoczky, Marc Vaudel, Helwig Hauser, Laura Garrison
# Thursday, September 17 | 17:30 – 19:00 • Guided Tour of Ljubljana | Prešeren square | https://maps.app.goo.gl/VhuMwobygB5CEaSr5 |
# Thursday, September 17 | 19:00 onwards • Conference Dinner | Gostilna na Gradu | https://www.jezersek.si/en/locations/ljubljana-castle |
# Friday, September 18 | 09:00 – 10:30 • Paper Session 4 – AI Interpretability, Interaction & Storytelling | LabTiles: A Small-Multiples Approach for Patient-Centered Blood Test Visualization |  | Tabea Grellmann, Bernhard Preim, Monique Meuschke
# Friday, September 18 | 09:00 – 10:30 • Paper Session 4 – AI Interpretability, Interaction & Storytelling | Whose Story Is It? Exploring Roles and Character Representation in Narrative Medical Visualization |  | Sophie Mlitzke, Janine Zöllner, Bernhard Preim, Monique Meuschke
# Friday, September 18 | 09:00 – 10:30 • Paper Session 4 – AI Interpretability, Interaction & Storytelling | Revealing Learned Medical Image Segmentation Strategies through Interactive Feature Map Ablation in CNNs |  | Annika Christina Mikliss, Elena Zimmermann, Thomas Schultz
# Friday, September 18 | 09:00 – 10:30 • Paper Session 4 – AI Interpretability, Interaction & Storytelling | Ordinal Deep Learning for Knee Effusion Grading in 3D MRI with Noisy Labels |  | Michal Jaroš, Martin Ropjak, Viktor Sisik, Lukáš Hudec, Peter Bluska, Zuzana Cernekova, Zuzana Berger Haladová
# Friday, September 18 | 09:00 – 10:30 • Paper Session 4 – AI Interpretability, Interaction & Storytelling | RGB-Based 2.5D Gesture Interaction with Volumetric Medical Data on an Autostereoscopic Display |  | Lisa Mueller, Bernhard Preim, Sebastian Krueger

# %%
by_day: dict[str, list[Paper]] = {}
for paper in papers:
    if paper.day not in by_day:
        by_day[paper.day] = []
    by_day[paper.day].append(paper)

# %%
for day, papers in by_day.items():
    print(f"## {day}")
    for paper in papers:
        if paper.link != "":
            continue
        print(f"Getting EG link for {paper.title}")
        eg_info = get_eg_link(paper.title)
        paper.link = eg_info.get("link", "")
        paper.doi = eg_info.get("doi", "")
        paper.authors = ", ".join(eg_info.get("authors", []))
        paper.thumbnail = eg_info.get("thumbnail", "")
        print(f"Found EG link: {paper.link}, DOI: {paper.doi}")
# Out:
# ## Wednesday, September 16
# ## Thursday, September 17
# Getting EG link for ConGAT: Context-Aware Graph Attention Visual Analysis for 3D Region of Interest Discovery in Multiplexed Microscopy Images
# Found EG link: , DOI:
# Getting EG link for MultiPASE: Shape-Aware Comparative 3D Genome Analysis
# Found EG link: https://diglib.eg.org/items/8e0ab2b4-c6af-45e0-bcbd-5fb00b37fbb5, DOI: 10.2312/vcbm20261015
# Getting EG link for Exploring Genes in the Brain Through Multimodal Views Driven by Disorder Ontologies
# Found EG link: https://diglib.eg.org/items/6282f7d7-caea-4a4e-ab2d-5aa537146d33, DOI: 10.2312/vcbm20261001
# Getting EG link for Interactive 3D Exploration of Large-Scale Neuronal Network Simulations with a Graph Lens
# Found EG link: https://diglib.eg.org/items/94fb9f50-d78b-4aa1-bf56-4601a570fe4c, DOI: 10.2312/vcbm20261012
# Getting EG link for An End-to-end Framework for Quantifying the Exploratory Behavior of Multicolumnar Neurons in Drosophila
# Found EG link: https://diglib.eg.org/items/5a3a176b-a519-4bfc-8adc-2e21b8785c49, DOI: 10.2312/vcbm20261016
# Getting EG link for Accurate Triangle Meshes of Biological Membranes Through Ridge Surface Reconstruction
# Found EG link: , DOI:
# Getting EG link for Reconstruction of 3D Whole Heart Mesh from 2D Cardiac Images
# Found EG link: https://diglib.eg.org/items/16c3d42f-a7f5-4a55-bb84-4d8d33f3cd2c, DOI: 10.2312/vcbm20261004
# Getting EG link for Vessel-straightening-based Registration for Aortic Flow Comparison
# Found EG link: https://diglib.eg.org/items/295bd743-ad29-4854-b6ac-62b4493011e4, DOI: 10.2312/vcbm20261006
# Getting EG link for Formalizing Structured Comparative Reporting for Hemodynamic Assessment in LAAO Planning
# Found EG link: , DOI:
# Getting EG link for Coupled Visualization-Quantification Pipeline for Time-Resolved Cement Injection Imaging: A Case Study
# Found EG link: , DOI:
# Getting EG link for MIA: A Visual Analytics System for Multimodal Spectral Imaging Data
# Found EG link: , DOI:
# Getting EG link for BeLOVE X-Talker: Interactive Heart-Brain Cross-Talk Explorer
# Found EG link: https://diglib.eg.org/items/4908a38f-6fea-4ad4-b4b8-5e4649b56b92, DOI: 10.2312/vcbm20261009
# Getting EG link for GutBrainViz: Interactive Exploration of Linked ICA Components across Brain Networks and Gut Microbiota
# Found EG link: https://diglib.eg.org/items/35d060ff-e8f6-413a-b4c9-b260ce927fcd, DOI: 10.2312/vcbm20261003
# Getting EG link for EEGlass: A Fully Interpretable EEG Dementia Screening Assistant
# Found EG link: https://diglib.eg.org/items/879ac1b0-27e2-439b-a90f-b9cc6013baff, DOI: 10.2312/vcbm20261002
# Getting EG link for Voidlytics for Leveraging Informative Missingness in the Study of Hyperemesis Gravidarum
# Found EG link: https://diglib.eg.org/items/6e62c9ff-1d81-48f8-8cf6-ab0a2edae671, DOI: 10.2312/vcbm20261014
# ## Friday, September 18
# Getting EG link for LabTiles: A Small-Multiples Approach for Patient-Centered Blood Test Visualization
# Found EG link: , DOI:
# Getting EG link for Whose Story Is It? Exploring Roles and Character Representation in Narrative Medical Visualization
# Found EG link: https://diglib.eg.org/items/8f17e975-25d4-4268-b714-acc43e89a3c4, DOI: 10.2312/vcbm20261000
# Getting EG link for Revealing Learned Medical Image Segmentation Strategies through Interactive Feature Map Ablation in CNNs
# Found EG link: https://diglib.eg.org/items/6256bfa4-196c-4841-8f7c-2b6b4a5e3d6f, DOI: 10.2312/vcbm20261005
# Getting EG link for Ordinal Deep Learning for Knee Effusion Grading in 3D MRI with Noisy Labels
# Found EG link: https://diglib.eg.org/items/6b71f77d-18cb-42a4-9434-3dcfef8c9131, DOI: 10.2312/vcbm20261010
# Getting EG link for RGB-Based 2.5D Gesture Interaction with Volumetric Medical Data on an Autostereoscopic Display
# Found EG link: https://diglib.eg.org/items/e9e4ddb6-8a7c-403f-86d4-74afae47e262, DOI: 10.2312/vcbm20261011

# %%
for i, (day, papers) in enumerate(by_day.items()):
    with open(f"g_day_{i + 2}.md", "w") as f:
        f.write(f"""---
title: VCBM Day {i + 2}
date: 2026-09-{i + 16}
---
# {day}
""")
        for paper in papers:
            f.write(f"""## {paper.title}
""")        
            if paper.thumbnail != "":
                f.write(f"\n![{paper.thumbnail}]({paper.thumbnail})\n\n")
            if paper.authors != "":
                f.write(f"_Authors: {paper.authors}_\n")
            if paper.link != "":
                f.write(f"- Link: [EG Digilib]({paper.link})\n")
            if paper.doi != "":
                f.write(f"- DOI: [{paper.doi}](https://doi.org/{paper.doi})\n")

# %%
len(entries)
# Out:
# 77

# %%
entries[5].name
# Out:
# 'h3'

# %%
import sys
sys.path.append('../../../processing')

# %%
from ocr import extract_poster_img, image_to_text

# %%
import tqdm
import cv2
from pathlib import Path
poster_path = Path("images/photos/posters")
warped_path = poster_path / "warped"
warped_path.mkdir(exist_ok=True)
imgs = list(poster_path.glob("*.jpeg"))
print(imgs)
# for img in tqdm(imgs):
#     print(img)
#     img_dat=cv2.imread(img)
#     final=scan(img_dat)
#     cv2.imwrite('out/'+img.split('/')[-1], final)
len(imgs)
for img in tqdm.tqdm(imgs):
    warped = extract_poster_img(str(img))
    target_path = warped_path / img.name.replace(".jpeg", "_warped.jpeg")

    cv2.imwrite(str(target_path), warped)
# Out:
# []
# 0it [00:00, ?it/s]

# %%
from utils import authors_text, biggest_text
import pandas as pd

# %%
results = []
warped_imgs = list(warped_path.glob("*.jpeg"))
for img in tqdm.tqdm(warped_imgs):
    text = image_to_text(str(img))
    authors = authors_text(text)
    title = biggest_text(text)
    results.append({
        "title": title,
        "authors": authors,
        "image_path": img
    })
results_df = pd.DataFrame(results)
# Out:
# 0it [00:00, ?it/s]

# %%
results_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
out_md_path =  "vcbm_poster_links.md"
with open(out_md_path, "w") as f:
    f.write("""---
title: VCBM Poster Links
date: 2026-09-16
---""")
    for _, row in results_df.iterrows():
        f.write(f"## {row['title']}\n")
        f.write(f"> Authors: {row['authors']}\n")
        f.write(f"![Poster Image]({row['image_path']})\n\n")
